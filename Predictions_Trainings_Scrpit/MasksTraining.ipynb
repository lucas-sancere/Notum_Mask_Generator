# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from tifffile import imread
from csbdeep.utils import axes_dict, plot_some, plot_history

from csbdeep.io import load_training_data
from csbdeep.models import Config, CARE
import os

os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# Using TensorFlow backend.

# %%
BaseDir = '/run/media/sancere/DATA/Lucas_NextonCreated_npz/'
NPZdata = 'Masks_Generator_bin2_onlyequalized'+ '.npz'

ModelDir ='/home/sancere/NextonDisk_1/Lucas_Model_to_use/Mask_Generator/'
ModelName = 'Masks_Generator_bin2_onlyequalized'


load_path = BaseDir + NPZdata

# %%
(X,Y), (X_val,Y_val), axes = load_training_data(load_path, validation_split=0.1, verbose=True)

c = axes_dict(axes)['C']
n_channel_in, n_channel_out = X.shape[c], Y.shape[c]
# Out:
# number of training images:	 25286
# number of validation images:	 2810
# image size (2D):		 (160, 160)
# axes:				 SYXC
# channels in / out:		 1 / 1

# %%
plt.figure(figsize=(12,5))
plot_some(X_val[:5],Y_val[:5])
plt.suptitle('5 example validation patches (top row: source, bottom row: target)');

# %%
config = Config(axes, n_channel_in, n_channel_out, probabilistic = False, unet_n_depth=5,unet_kern_size=7,train_epochs= 70, train_batch_size = 64, train_reduce_lr={'patience': 5, 'factor': 0.5})
print(config)
vars(config)
# Out:
# Config(axes='YXC', n_channel_in=1, n_channel_out=1, n_dim=2, probabilistic=False, train_batch_size=64, train_checkpoint='weights_best.h5', train_checkpoint_epoch='weights_now.h5', train_checkpoint_last='weights_last.h5', train_epochs=70, train_learning_rate=0.0004, train_loss='mae', train_reduce_lr={'patience': 5, 'factor': 0.5}, train_steps_per_epoch=400, train_tensorboard=True, unet_input_shape=(None, None, 1), unet_kern_size=7, unet_last_activation='linear', unet_n_depth=5, unet_n_first=32, unet_residual=True)
# {'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 1,
#  'n_channel_out': 1,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'probabilistic': False,
#  'unet_residual': True,
#  'unet_n_depth': 5,
#  'unet_kern_size': 7,
#  'unet_n_first': 32,
#  'unet_last_activation': 'linear',
#  'unet_input_shape': (None, None, 1),
#  'train_loss': 'mae',
#  'train_epochs': 70,
#  'train_steps_per_epoch': 400,
#  'train_learning_rate': 0.0004,
#  'train_batch_size': 64,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'patience': 5, 'factor': 0.5}}

# %%
model = CARE(config = config, name = ModelName, basedir = ModelDir)
#model.load_weights(ModelDir + ModelName + '/' + 'weights_best.h5')
# Out:
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.

# %%
history = model.train(X,Y, validation_data=(X_val,Y_val))
# Out:
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/csbdeep/utils/tf.py:240: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/csbdeep/utils/tf.py:268: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/csbdeep/utils/tf.py:275: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/70
# 400/400 [==============================] - 209s 522ms/step - loss: 11.3253 - mse: 67290.6087 - mae: 11.3253 - val_loss: 0.0412 - val_mse: 0.0143 - val_mae: 0.0412
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/csbdeep/utils/tf.py:303: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/70
# 400/400 [==============================] - 194s 486ms/step - loss: 0.0379 - mse: 0.0125 - mae: 0.0379 - val_loss: 0.0327 - val_mse: 0.0116 - val_mae: 0.0327
# Epoch 3/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0314 - mse: 0.0113 - mae: 0.0314 - val_loss: 0.0324 - val_mse: 0.0119 - val_mae: 0.0324
# Epoch 4/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0275 - mse: 0.0102 - mae: 0.0275 - val_loss: 0.0238 - val_mse: 0.0098 - val_mae: 0.0238
# Epoch 5/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0257 - mse: 0.0097 - mae: 0.0257 - val_loss: 0.0227 - val_mse: 0.0089 - val_mae: 0.0227
# Epoch 6/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0240 - mse: 0.0089 - mae: 0.0240 - val_loss: 0.0241 - val_mse: 0.0107 - val_mae: 0.0241
# Epoch 7/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0211 - mse: 0.0086 - mae: 0.0211 - val_loss: 0.0197 - val_mse: 0.0087 - val_mae: 0.0197
# Epoch 8/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0200 - mse: 0.0081 - mae: 0.0200 - val_loss: 0.0176 - val_mse: 0.0082 - val_mae: 0.0176
# Epoch 9/70
# 400/400 [==============================] - 193s 484ms/step - loss: 0.0202 - mse: 0.0079 - mae: 0.0202 - val_loss: 0.0195 - val_mse: 0.0086 - val_mae: 0.0195
# Epoch 10/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0184 - mse: 0.0076 - mae: 0.0184 - val_loss: 0.0163 - val_mse: 0.0078 - val_mae: 0.0163
# Epoch 11/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0175 - mse: 0.0074 - mae: 0.0175 - val_loss: 0.0218 - val_mse: 0.0081 - val_mae: 0.0218
# Epoch 12/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0190 - mse: 0.0075 - mae: 0.0190 - val_loss: 0.0160 - val_mse: 0.0071 - val_mae: 0.0160
# Epoch 13/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0181 - mse: 0.0080 - mae: 0.0181 - val_loss: 0.0247 - val_mse: 0.0110 - val_mae: 0.0247
# Epoch 14/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0171 - mse: 0.0072 - mae: 0.0171 - val_loss: 0.0156 - val_mse: 0.0077 - val_mae: 0.0156
# Epoch 15/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0198 - mse: 0.0071 - mae: 0.0198 - val_loss: 0.0129 - val_mse: 0.0071 - val_mae: 0.0129
# Epoch 16/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0167 - mse: 0.0068 - mae: 0.0167 - val_loss: 0.0259 - val_mse: 0.0074 - val_mae: 0.0259
# Epoch 17/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0173 - mse: 0.0071 - mae: 0.0173 - val_loss: 0.0200 - val_mse: 0.0085 - val_mae: 0.0200
# Epoch 18/70
# 400/400 [==============================] - 193s 484ms/step - loss: 0.0171 - mse: 0.0070 - mae: 0.0171 - val_loss: 0.0137 - val_mse: 0.0069 - val_mae: 0.0137
# Epoch 19/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0178 - mse: 0.0066 - mae: 0.0178 - val_loss: 0.0149 - val_mse: 0.0070 - val_mae: 0.0149
# Epoch 20/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0175 - mse: 0.0065 - mae: 0.0175 - val_loss: 0.0166 - val_mse: 0.0068 - val_mae: 0.0166
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 21/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0104 - mse: 0.0057 - mae: 0.0104 - val_loss: 0.0116 - val_mse: 0.0064 - val_mae: 0.0116
# Epoch 22/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0105 - mse: 0.0055 - mae: 0.0105 - val_loss: 0.0108 - val_mse: 0.0063 - val_mae: 0.0108
# Epoch 23/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0119 - mse: 0.0057 - mae: 0.0119 - val_loss: 0.0112 - val_mse: 0.0060 - val_mae: 0.0112
# Epoch 24/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0118 - mse: 0.0053 - mae: 0.0118 - val_loss: 0.0115 - val_mse: 0.0060 - val_mae: 0.0115
# Epoch 25/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0117 - mse: 0.0054 - mae: 0.0117 - val_loss: 0.0175 - val_mse: 0.0064 - val_mae: 0.0175
# Epoch 26/70
# 400/400 [==============================] - 193s 484ms/step - loss: 0.0113 - mse: 0.0053 - mae: 0.0113 - val_loss: 0.0099 - val_mse: 0.0062 - val_mae: 0.0099
# Epoch 27/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0120 - mse: 0.0052 - mae: 0.0120 - val_loss: 0.0136 - val_mse: 0.0061 - val_mae: 0.0136
# Epoch 28/70
# 400/400 [==============================] - 197s 493ms/step - loss: 0.0110 - mse: 0.0053 - mae: 0.0110 - val_loss: 0.0153 - val_mse: 0.0076 - val_mae: 0.0153
# Epoch 29/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0120 - mse: 0.0051 - mae: 0.0120 - val_loss: 0.0100 - val_mse: 0.0061 - val_mae: 0.0100
# Epoch 30/70
# 400/400 [==============================] - 193s 484ms/step - loss: 0.0111 - mse: 0.0050 - mae: 0.0111 - val_loss: 0.0129 - val_mse: 0.0058 - val_mae: 0.0129
# Epoch 31/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0119 - mse: 0.0051 - mae: 0.0119 - val_loss: 0.0144 - val_mse: 0.0059 - val_mae: 0.0144
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 32/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0088 - mse: 0.0044 - mae: 0.0088 - val_loss: 0.0102 - val_mse: 0.0056 - val_mae: 0.0102
# Epoch 33/70
# 400/400 [==============================] - 193s 484ms/step - loss: 0.0085 - mse: 0.0042 - mae: 0.0085 - val_loss: 0.0085 - val_mse: 0.0055 - val_mae: 0.0085
# Epoch 34/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0072 - mse: 0.0041 - mae: 0.0072 - val_loss: 0.0124 - val_mse: 0.0056 - val_mae: 0.0124
# Epoch 35/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0079 - mse: 0.0040 - mae: 0.0079 - val_loss: 0.0083 - val_mse: 0.0054 - val_mae: 0.0083
# Epoch 36/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0078 - mse: 0.0041 - mae: 0.0078 - val_loss: 0.0081 - val_mse: 0.0054 - val_mae: 0.0081
# Epoch 37/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0081 - mse: 0.0041 - mae: 0.0081 - val_loss: 0.0110 - val_mse: 0.0053 - val_mae: 0.0110
# Epoch 38/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0085 - mse: 0.0039 - mae: 0.0085 - val_loss: 0.0114 - val_mse: 0.0054 - val_mae: 0.0114
# Epoch 39/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0076 - mse: 0.0038 - mae: 0.0076 - val_loss: 0.0102 - val_mse: 0.0053 - val_mae: 0.0102
# Epoch 40/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0080 - mse: 0.0038 - mae: 0.0080 - val_loss: 0.0084 - val_mse: 0.0052 - val_mae: 0.0084
# Epoch 41/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0075 - mse: 0.0036 - mae: 0.0075 - val_loss: 0.0100 - val_mse: 0.0054 - val_mae: 0.0100
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 42/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0059 - mse: 0.0035 - mae: 0.0059 - val_loss: 0.0071 - val_mse: 0.0050 - val_mae: 0.0071
# Epoch 43/70
# 400/400 [==============================] - 193s 484ms/step - loss: 0.0055 - mse: 0.0033 - mae: 0.0055 - val_loss: 0.0074 - val_mse: 0.0052 - val_mae: 0.0074
# Epoch 44/70
# 400/400 [==============================] - 193s 484ms/step - loss: 0.0059 - mse: 0.0031 - mae: 0.0059 - val_loss: 0.0073 - val_mse: 0.0049 - val_mae: 0.0073
# Epoch 45/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0055 - mse: 0.0032 - mae: 0.0055 - val_loss: 0.0085 - val_mse: 0.0054 - val_mae: 0.0085
# Epoch 46/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0055 - mse: 0.0032 - mae: 0.0055 - val_loss: 0.0073 - val_mse: 0.0049 - val_mae: 0.0073
# Epoch 47/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0063 - mse: 0.0032 - mae: 0.0063 - val_loss: 0.0077 - val_mse: 0.0049 - val_mae: 0.0077
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 48/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0048 - mse: 0.0029 - mae: 0.0048 - val_loss: 0.0066 - val_mse: 0.0048 - val_mae: 0.0066
# Epoch 49/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0046 - mse: 0.0028 - mae: 0.0046 - val_loss: 0.0067 - val_mse: 0.0049 - val_mae: 0.0067
# Epoch 50/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0048 - mse: 0.0029 - mae: 0.0048 - val_loss: 0.0066 - val_mse: 0.0048 - val_mae: 0.0066
# Epoch 51/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0047 - mse: 0.0029 - mae: 0.0047 - val_loss: 0.0068 - val_mse: 0.0048 - val_mae: 0.0068
# Epoch 52/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0045 - mse: 0.0027 - mae: 0.0045 - val_loss: 0.0064 - val_mse: 0.0047 - val_mae: 0.0064
# Epoch 53/70
# 400/400 [==============================] - 193s 484ms/step - loss: 0.0048 - mse: 0.0027 - mae: 0.0048 - val_loss: 0.0065 - val_mse: 0.0048 - val_mae: 0.0065
# Epoch 54/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0046 - mse: 0.0028 - mae: 0.0046 - val_loss: 0.0067 - val_mse: 0.0048 - val_mae: 0.0067
# Epoch 55/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0045 - mse: 0.0026 - mae: 0.0045 - val_loss: 0.0067 - val_mse: 0.0047 - val_mae: 0.0067
# Epoch 56/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0044 - mse: 0.0027 - mae: 0.0044 - val_loss: 0.0065 - val_mse: 0.0047 - val_mae: 0.0065
# Epoch 57/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0048 - mse: 0.0027 - mae: 0.0048 - val_loss: 0.0073 - val_mse: 0.0047 - val_mae: 0.0073
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 58/70
# 400/400 [==============================] - 198s 494ms/step - loss: 0.0041 - mse: 0.0025 - mae: 0.0041 - val_loss: 0.0063 - val_mse: 0.0047 - val_mae: 0.0063
# Epoch 59/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0041 - mse: 0.0025 - mae: 0.0041 - val_loss: 0.0063 - val_mse: 0.0047 - val_mae: 0.0063
# Epoch 60/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0040 - mse: 0.0025 - mae: 0.0040 - val_loss: 0.0063 - val_mse: 0.0047 - val_mae: 0.0063
# Epoch 61/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0040 - mse: 0.0024 - mae: 0.0040 - val_loss: 0.0063 - val_mse: 0.0047 - val_mae: 0.0063
# Epoch 62/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0040 - mse: 0.0025 - mae: 0.0040 - val_loss: 0.0062 - val_mse: 0.0046 - val_mae: 0.0062
# Epoch 63/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0040 - mse: 0.0024 - mae: 0.0040 - val_loss: 0.0063 - val_mse: 0.0046 - val_mae: 0.0063
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 64/70
# 400/400 [==============================] - 194s 484ms/step - loss: 0.0038 - mse: 0.0023 - mae: 0.0038 - val_loss: 0.0062 - val_mse: 0.0047 - val_mae: 0.0062
# Epoch 65/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0039 - mse: 0.0024 - mae: 0.0039 - val_loss: 0.0061 - val_mse: 0.0046 - val_mae: 0.0061
# Epoch 66/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0038 - mse: 0.0023 - mae: 0.0038 - val_loss: 0.0061 - val_mse: 0.0046 - val_mae: 0.0061
# Epoch 67/70
# 400/400 [==============================] - 193s 484ms/step - loss: 0.0038 - mse: 0.0023 - mae: 0.0038 - val_loss: 0.0061 - val_mse: 0.0046 - val_mae: 0.0061
# Epoch 68/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0038 - mse: 0.0023 - mae: 0.0038 - val_loss: 0.0061 - val_mse: 0.0046 - val_mae: 0.0061
# Epoch 69/70
# 400/400 [==============================] - 194s 485ms/step - loss: 0.0037 - mse: 0.0023 - mae: 0.0037 - val_loss: 0.0061 - val_mse: 0.0046 - val_mae: 0.0061
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 70/70
# 400/400 [==============================] - 193s 483ms/step - loss: 0.0037 - mse: 0.0023 - mae: 0.0037 - val_loss: 0.0061 - val_mse: 0.0046 - val_mae: 0.0061
#
# Loading network weights from 'weights_best.h5'.

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss'],['mse','val_mse','mae','val_mae']);
# Out:
# ['loss', 'lr', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse']

# %%
plt.figure(figsize=(12,7))
_P = model.keras_model.predict(X_val[:5])
if config.probabilistic:
    _P = _P[...,:(_P.shape[-1]//2)]
plot_some(X_val[:5],Y_val[:5],_P,pmax=99.5)
plt.suptitle('5 example validation patches\n'      
             'top row: input (source),  '          
             'middle row: target (ground truth),  '
             'bottom row: predicted from source');

# %%
model.export_TF()
# Out:
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/csbdeep/utils/tf.py:88: The name tf.saved_model.builder.SavedModelBuilder is deprecated. Please use tf.compat.v1.saved_model.builder.SavedModelBuilder instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/csbdeep/utils/tf.py:89: The name tf.saved_model.signature_def_utils.predict_signature_def is deprecated. Please use tf.compat.v1.saved_model.signature_def_utils.predict_signature_def instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/csbdeep/utils/tf.py:93: The name tf.saved_model.signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY is deprecated. Please use tf.saved_model.DEFAULT_SERVING_SIGNATURE_DEF_KEY instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/csbdeep/utils/tf.py:95: The name tf.saved_model.tag_constants.SERVING is deprecated. Please use tf.saved_model.SERVING instead.
#
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /tmp/tmp5wnmusb3/model/saved_model.pb
#
# Model exported in TensorFlow's SavedModel format:
# /home/sancere/NextonDisk_1/Lucas_Model_to_use/Mask_Generator/Masks_Generator_bin2_onlyequalized/TF_SavedModel.zip
